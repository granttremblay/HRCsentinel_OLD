# %%
import Chandra.Time
import Ska.engarchive.fetch as fetch

from Ska.engarchive.utils import logical_intervals

import time

import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline
import numpy as np

# %%
start = '2009:002'
stop = '2016:007'

voltage = fetch.MSID('2PRBSVL', start=start, stop=stop, filter_bad=True, stat='daily')
current = fetch.MSID('2PRBSCR', start=start, stop=stop, filter_bad=True, stat='daily')

# %%
voltage.plot(fmt='')

# %%
bad_vals_mask = (voltage.vals > 28.3)

# %%
bad_vals_mask
# Out:
# array([False, False, False, ..., False, False, False], dtype=bool)

# %%
vol = voltage.filter_bad(bad_vals_mask)

# %%
vol.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-75a18ec6e30d> in <module>()
# ----> 1 vol.plot()
#
# AttributeError: 'NoneType' object has no attribute 'plot'
